# %% [markdown]
# # Retail & Food Services Sales Analytics Dashboard
#
# This notebook will be used for loading, cleaning, and exploring the Online Retail dataset.

# %% [markdown]
# ## Planned Cleaning Steps
#
# 1. Load the Excel dataset
# 2. Inspect columns and data types
# 3. Remove cancelled invoices
# 4. Remove rows with invalid quantity or unit price
# 5. Handle missing customer IDs
# 6. Create total revenue column
# 7. Export cleaned CSV files for Power BI and SQL analysis

# %%
import pandas as pd
import numpy as np

raw_path = '../data/raw/Online Retail.xlsx'

# df = pd.read_excel(raw_path)
# df.head()
